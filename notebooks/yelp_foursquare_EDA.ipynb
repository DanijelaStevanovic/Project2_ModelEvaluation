# %%
# imports
import pandas as pd
import json 
import requests
from datetime import datetime
import numpy as np 
import os 
from pathlib import Path  
import re

# %% [markdown]
# # Foursquare

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
df_bike = pd.read_csv('data/city_bikes.csv')
df_bike.head()
# Out:
#    Unnamed: 0   latitude  longitude  free_bikes  \
# 0           0  43.665269 -79.319796          15
# 1           1  43.671420 -79.445947           4
# 2           2  43.666224 -79.317693          19
# 3           3  43.653236 -79.376716           9
# 4           4  43.663722 -79.380288           2
#
#                          stationsid
# 0  fb337bbed72e2be090071e199899b2be
# 1  4ff88d5880e71aa40d34cfe5d09b0ca7
# 2  a09c67c0b419654d907c9134b108e328
# 3  d6a9daee68070a8b106cfb598d81308c
# 4  8f8af40d9388c8a3962559e8681d3db7

# %%
def stations_location(ll_value):
        
    url = f'https://api.foursquare.com/v3/places/search?query=Bar&ll={ll_value}&radius=1000&fields=fsq_id%2Cname%2Clocation%2Ccategories%2Cpopularity%2Crating&sort=POPULARITY'
    api_key = os.environ["FOURSQUARE_API_KEY"]
    headers = {
        "accept": "application/json",
        "Authorization": api_key
               }

    response = requests.get(url, headers=headers).json()
    

    list_of_dict = []
    for poi in response['results']:
        categories = poi.get('categories', None)
        cat_id = categories[0]['id'] if len(categories) > 0 else None
        category_name = categories[0]['name'] if len(categories) > 0 else None

        loci_poi_dict = {
              'lat-long': f'{ll_value}'
            , 'fsq_id': poi['fsq_id']
            , 'cat_id': cat_id
            , 'category_name': category_name
            , 'categories': categories
            , 'name': poi.get('name', None)
            , 'address': poi.get('location', {}).get('formatted_address', None)
            , 'city': poi.get('location', {}).get('locality', None)
            , 'country': poi.get('location', {}).get('country', None)
            , 'popularity': poi.get('popularity', None)
            , 'rating': poi.get('rating', None)

        }
        list_of_dict.append(loci_poi_dict)
    return pd.DataFrame(list_of_dict)

# %%
df_bike.dropna(subset=['latitude', 'longitude'], inplace=True)

df_bike['ll'] = df_bike['latitude'].astype(str) + ',' + df_bike['longitude'].astype(str)
df_bike = df_bike[df_bike['ll'] != '0.0,0.0']
print(df_bike.shape)
print(df_bike.dtypes)
df_bike.head()
# Out:
# (656, 6)
# Unnamed: 0      int64
# latitude      float64
# longitude     float64
# free_bikes      int64
# stationsid     object
# ll             object
# dtype: object
#    Unnamed: 0   latitude  longitude  free_bikes  \
# 0           0  43.665269 -79.319796          15
# 1           1  43.671420 -79.445947           4
# 2           2  43.666224 -79.317693          19
# 3           3  43.653236 -79.376716           9
# 4           4  43.663722 -79.380288           2
#
#                          stationsid                    ll
# 0  fb337bbed72e2be090071e199899b2be  43.665269,-79.319796
# 1  4ff88d5880e71aa40d34cfe5d09b0ca7   43.67142,-79.445947
# 2  a09c67c0b419654d907c9134b108e328  43.666224,-79.317693
# 3  d6a9daee68070a8b106cfb598d81308c  43.653236,-79.376716
# 4  8f8af40d9388c8a3962559e8681d3db7  43.663722,-79.380288

# %%
ll_bike = df_bike['ll']
ll_bike.head()
# Out:
# 0    43.665269,-79.319796
# 1     43.67142,-79.445947
# 2    43.666224,-79.317693
# 3    43.653236,-79.376716
# 4    43.663722,-79.380288
# Name: ll, dtype: object

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
df_list_fsq = []
for i in ll_bike:
    next = stations_location(i)
    df_list_fsq.append(next)

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
df_fsq = pd.DataFrame()
x = pd.DataFrame()

for df_i in df_list_fsq:
    x = pd.concat([df_fsq, df_i])
    df_fsq = x

# %%
df_fsq.shape
# Out:
# (5797, 11)

# %%
df_fsq.head()
# Out:
#                lat-long                    fsq_id  cat_id category_name  \
# 0  43.665269,-79.319796  4b12cd56f964a5206d8e23e3   13049         Diner
# 1  43.665269,-79.319796  4da22f3ad686b60c2bb1b428   13018           Pub
# 2  43.665269,-79.319796  54b47574498e6b087d957fa2   13003           Bar
# 3  43.665269,-79.319796  60ce6c2fe180036cc18a8b13   13010      Dive Bar
# 4  43.665269,-79.319796  4ea9b2c0cc217eb08e070a93   13031  Burger Joint
#
#                                           categories                    name  \
# 0  [{'id': 13049, 'name': 'Diner', 'icon': {'pref...    Occasions Restaurant
# 1  [{'id': 13018, 'name': 'Pub', 'icon': {'prefix...        Queen's Head Pub
# 2  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...  Eulalie's Corner Store
# 3  [{'id': 13010, 'name': 'Dive Bar', 'icon': {'p...            Betty's East
# 4  [{'id': 13031, 'name': 'Burger Joint', 'icon':...       Lazy Daisy's Cafe
#
#                                              address     city country  \
# 0  30 Eastwood Rd (Gainsborough Road), Toronto ON...  Toronto      CA
# 1    1214 Queen St E (Leslie St), Toronto ON M4M 1L7  Toronto      CA
# 2    1438 Gerrard St E (Ashdale), Toronto ON M4L 1Z8  Toronto      CA
# 3                1301 Queen St E, Toronto ON M4L 1C2  Toronto      CA
# 4  1515 Gerrard St E (at Coxwell Ave), Toronto ON...  Toronto      CA
#
#   popularity rating
# 0   0.963599    7.4
# 1   0.962753    5.6
# 2   0.957616    6.9
# 3   0.954275    NaN
# 4   0.939122    7.4

# %%
# Save csv

filepath = Path('data/data_Foursquare.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  

df_fsq.to_csv(filepath, index=False) 
df_fsq.head(50)
# Out:
#                lat-long                    fsq_id  cat_id  \
# 0  43.665269,-79.319796  4b12cd56f964a5206d8e23e3   13049
# 1  43.665269,-79.319796  4da22f3ad686b60c2bb1b428   13018
# 2  43.665269,-79.319796  54b47574498e6b087d957fa2   13003
# 3  43.665269,-79.319796  60ce6c2fe180036cc18a8b13   13010
# 4  43.665269,-79.319796  4ea9b2c0cc217eb08e070a93   13031
# 5  43.665269,-79.319796  4fd52f42e4b0b916eb02ab1b   13064
# 6  43.665269,-79.319796  4b6bb0cef964a520b6152ce3   10032
# 7  43.665269,-79.319796  584b6fef65e7c76fc4e5c627   13003
# 8  43.665269,-79.319796  4b0ff2a5f964a520a16623e3   13018
# 9  43.665269,-79.319796  5f5aa25c6fa9260f1e84871c   13276
# 0   43.67142,-79.445947  5fe4bf11ec39e873a5811659   13018
# 1   43.67142,-79.445947  4f14a5cbe4b072565fe420b4   13272
# 2   43.67142,-79.445947  5aabed888fb09e249951f426   13276
# 3   43.67142,-79.445947  5753753b498eeb535c53aed5   13003
# 4   43.67142,-79.445947  4cf0a27f7bf3b60ce9095b7f   10032
# 5   43.67142,-79.445947  62dc5c20e88f9b2583eedd18   13025
# 6   43.67142,-79.445947  5cca5678326fb1002b94bc06   13003
# 7   43.67142,-79.445947  5c4e727db1538e002c85063b   13303
# 8   43.67142,-79.445947  4e15d960fa764fb14aeae8bb   13016
# 9   43.67142,-79.445947  4adcc512f964a5209f2f21e3   13022
# 0  43.666224,-79.317693  4b12cd56f964a5206d8e23e3   13049
# 1  43.666224,-79.317693  54b47574498e6b087d957fa2   13003
# 2  43.666224,-79.317693  60ce6c2fe180036cc18a8b13   13010
# 3  43.666224,-79.317693  4ea9b2c0cc217eb08e070a93   13031
# 4  43.666224,-79.317693  4fd52f42e4b0b916eb02ab1b   13064
# 5  43.666224,-79.317693  584b6fef65e7c76fc4e5c627   13003
# 6  43.666224,-79.317693  4b0ff2a5f964a520a16623e3   13018
# 7  43.666224,-79.317693  5f5aa25c6fa9260f1e84871c   13276
# 8  43.666224,-79.317693  4ce88b709f776ea832f05e22   12069
# 9  43.666224,-79.317693  53d82743498e02dad4ccb302   13010
# 0  43.653236,-79.376716  4ad9ffbbf964a520091d21e3   13003
# 1  43.653236,-79.376716  4af96fbbf964a520c01122e3   19009
# 2  43.653236,-79.376716  601d14d442fb60302fae8306   13006
# 3  43.653236,-79.376716  4ad4c05df964a5203cf620e3   13013
# 4  43.653236,-79.376716  4d2b615e342d6dcb2b8115cb   13016
# 5  43.653236,-79.376716  4cdc78defc9737042ba2d505   13013
# 6  43.653236,-79.376716  4a9f21c0f964a520a63c20e3   13006
# 7  43.653236,-79.376716  4d306dd82748b60c62b6dba0   13065
# 8  43.653236,-79.376716  4ad4c05df964a52059f620e3   13065
# 9  43.653236,-79.376716  57fcf30c498e1b3a29dc46a5   19056
# 0  43.663722,-79.380288  4ad9ffbbf964a520091d21e3   13003
# 1  43.663722,-79.380288  4fe4a773e4b0ef61f5212ecd   13099
# 2  43.663722,-79.380288  4ad887d2f964a520111221e3   13011
# 3  43.663722,-79.380288  4a9f21c0f964a520a63c20e3   13006
# 4  43.663722,-79.380288  4ada0042f964a520111d21e3   13383
# 5  43.663722,-79.380288  4f4cee23e4b05b49b42c92a9   13003
# 6  43.663722,-79.380288  4bb942a7cf2fc9b6596ca002   13383
# 7  43.663722,-79.380288  4af4e6e2f964a52052f721e3   13026
# 8  43.663722,-79.380288  4aefac72f964a520ded921e3   13006
# 9  43.663722,-79.380288  4ab2b0b9f964a520e56b20e3   13003
#
#                     category_name  \
# 0                           Diner
# 1                             Pub
# 2                             Bar
# 3                        Dive Bar
# 4                    Burger Joint
# 5                        Pizzeria
# 6                      Night Club
# 7                             Bar
# 8                             Pub
# 9                Sushi Restaurant
# 0                             Pub
# 1                Ramen Restaurant
# 2                Sushi Restaurant
# 3                             Bar
# 4                      Night Club
# 5                        Wine Bar
# 6                             Bar
# 7              Mexican Restaurant
# 8                          Lounge
# 9                      Sports Bar
# 0                           Diner
# 1                             Bar
# 2                        Dive Bar
# 3                    Burger Joint
# 4                        Pizzeria
# 5                             Bar
# 6                             Pub
# 7                Sushi Restaurant
# 8  Government Department / Agency
# 9                        Dive Bar
# 0                             Bar
# 1                         Lodging
# 2                        Beer Bar
# 3                       Hotel Bar
# 4                          Lounge
# 5                       Hotel Bar
# 6                        Beer Bar
# 7                      Restaurant
# 8                      Restaurant
# 9                   Travel Lounge
# 0                             Bar
# 1              Chinese Restaurant
# 2                         Gay Bar
# 3                        Beer Bar
# 4                      Steakhouse
# 5                             Bar
# 6                      Steakhouse
# 7                       BBQ Joint
# 8                        Beer Bar
# 9                             Bar
#
#                                           categories  \
# 0  [{'id': 13049, 'name': 'Diner', 'icon': {'pref...
# 1  [{'id': 13018, 'name': 'Pub', 'icon': {'prefix...
# 2  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...
# 3  [{'id': 13010, 'name': 'Dive Bar', 'icon': {'p...
# 4  [{'id': 13031, 'name': 'Burger Joint', 'icon':...
# 5  [{'id': 13064, 'name': 'Pizzeria', 'icon': {'p...
# 6  [{'id': 10032, 'name': 'Night Club', 'icon': {...
# 7  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...
# 8  [{'id': 13018, 'name': 'Pub', 'icon': {'prefix...
# 9  [{'id': 13276, 'name': 'Sushi Restaurant', 'ic...
# 0  [{'id': 13018, 'name': 'Pub', 'icon': {'prefix...
# 1  [{'id': 13272, 'name': 'Ramen Restaurant', 'ic...
# 2  [{'id': 13276, 'name': 'Sushi Restaurant', 'ic...
# 3  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...
# 4  [{'id': 10032, 'name': 'Night Club', 'icon': {...
# 5  [{'id': 13025, 'name': 'Wine Bar', 'icon': {'p...
# 6  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...
# 7  [{'id': 13303, 'name': 'Mexican Restaurant', '...
# 8  [{'id': 13016, 'name': 'Lounge', 'icon': {'pre...
# 9  [{'id': 13022, 'name': 'Sports Bar', 'icon': {...
# 0  [{'id': 13049, 'name': 'Diner', 'icon': {'pref...
# 1  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...
# 2  [{'id': 13010, 'name': 'Dive Bar', 'icon': {'p...
# 3  [{'id': 13031, 'name': 'Burger Joint', 'icon':...
# 4  [{'id': 13064, 'name': 'Pizzeria', 'icon': {'p...
# 5  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...
# 6  [{'id': 13018, 'name': 'Pub', 'icon': {'prefix...
# 7  [{'id': 13276, 'name': 'Sushi Restaurant', 'ic...
# 8  [{'id': 12069, 'name': 'Government Department ...
# 9  [{'id': 13010, 'name': 'Dive Bar', 'icon': {'p...
# 0  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...
# 1  [{'id': 19009, 'name': 'Lodging', 'icon': {'pr...
# 2  [{'id': 13006, 'name': 'Beer Bar', 'icon': {'p...
# 3  [{'id': 13013, 'name': 'Hotel Bar', 'icon': {'...
# 4  [{'id': 13016, 'name': 'Lounge', 'icon': {'pre...
# 5  [{'id': 13013, 'name': 'Hotel Bar', 'icon': {'...
# 6  [{'id': 13006, 'name': 'Beer Bar', 'icon': {'p...
# 7  [{'id': 13065, 'name': 'Restaurant', 'icon': {...
# 8  [{'id': 13065, 'name': 'Restaurant', 'icon': {...
# 9  [{'id': 19056, 'name': 'Travel Lounge', 'icon'...
# 0  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...
# 1  [{'id': 13099, 'name': 'Chinese Restaurant', '...
# 2  [{'id': 13011, 'name': 'Gay Bar', 'icon': {'pr...
# 3  [{'id': 13006, 'name': 'Beer Bar', 'icon': {'p...
# 4  [{'id': 13383, 'name': 'Steakhouse', 'icon': {...
# 5  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...
# 6  [{'id': 13383, 'name': 'Steakhouse', 'icon': {...
# 7  [{'id': 13026, 'name': 'BBQ Joint', 'icon': {'...
# 8  [{'id': 13006, 'name': 'Beer Bar', 'icon': {'p...
# 9  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...
#
#                                              name  \
# 0                            Occasions Restaurant
# 1                                Queen's Head Pub
# 2                          Eulalie's Corner Store
# 3                                    Betty's East
# 4                               Lazy Daisy's Cafe
# 5                                         O Sushi
# 6                                    Duke of York
# 7                                Lloyd's on Queen
# 8                      Murphy's Law Irish Pub Inc
# 9                                      Toto Sushi
# 0                             Century Park Tavern
# 1                                California Sushi
# 2                                         Shunoko
# 3                            The Greater Good Bar
# 4                                     Epic Lounge
# 5                       Paradise Grapevine Winery
# 6                                    Limón Lounge
# 7                               El Sazon Mexicano
# 8                             Castello Sports Bar
# 9                  Boo Radleys Junction Bar N Gri
# 0                            Occasions Restaurant
# 1                          Eulalie's Corner Store
# 2                                    Betty's East
# 3                               Lazy Daisy's Cafe
# 4                                         O Sushi
# 5                                Lloyd's on Queen
# 6                      Murphy's Law Irish Pub Inc
# 7                                      Toto Sushi
# 8                           Royal Canadian Legion
# 9                                   Jenny's Place
# 0                                    Jack Astor's
# 1                 One King West Hotel . Residence
# 2                       CRAFT Beer Market Toronto
# 3                                     Library Bar
# 4                            Earl's Kitchen & Bar
# 5                                     Club Lounge
# 6                                   The 3 Brewers
# 7                              Trattoria Mercatto
# 8                          Canoe Restaurant & Bar
# 9  Executive Lounge Toronto Marriott Eaton Centre
# 0                                    Jack Astor's
# 1                                    Spring Sushi
# 2                                 Hair of the Dog
# 3                                   The 3 Brewers
# 4                                    Jack Astor’s
# 5                                      Jugo Juice
# 6                        The Keg Steakhouse & Bar
# 7                         St. Louis Bar and Grill
# 8                                    Imperial Pub
# 9               The Queen and Beaver Public House
#
#                                              address     city country  \
# 0  30 Eastwood Rd (Gainsborough Road), Toronto ON...  Toronto      CA
# 1    1214 Queen St E (Leslie St), Toronto ON M4M 1L7  Toronto      CA
# 2    1438 Gerrard St E (Ashdale), Toronto ON M4L 1Z8  Toronto      CA
# 3                1301 Queen St E, Toronto ON M4L 1C2  Toronto      CA
# 4  1515 Gerrard St E (at Coxwell Ave), Toronto ON...  Toronto      CA
# 5          6 Coxwell Ave (Queen), Toronto ON M4L 3A7  Toronto      CA
# 6  1225 Queen St E (at Leslie St), Toronto ON M4M...  Toronto      CA
# 7                1298 Queen St E, Toronto ON M4L 1C4  Toronto      CA
# 8  1702 Queen St E (at Kingston Rd.), Toronto ON ...  Toronto      CA
# 9  1455 Gerrard St E (Craven Rd), Toronto ON M4L 1Z9  Toronto      CA
# 0               33 Powerhouse St, Toronto ON M6H 0C7  Toronto      CA
# 1         1238 Saint Clair Ave W, Toronto ON M6E 1B7  Toronto      CA
# 2  1201 St Clair Ave W (at Dufferin St), Toronto ...  Toronto      CA
# 3  229 Geary Ave (at Dufferin St), Toronto ON M6H...  Toronto      CA
# 4  1355 Saint Clair Ave W (Lansdowne Ave.), Toron...  Toronto      CA
# 5                  218 Geary Ave, Toronto ON M6H 2C3  Toronto      CA
# 6            1089 St Clair Ave W, Toronto ON M6E 1A8  Toronto      CA
# 7            1284 St Clair Ave W, Toronto ON M6E 1C1  Toronto      CA
# 8            1468 St Clair Ave W, Toronto ON M6E 1C6  Toronto      CA
# 9  1482 Dupont Ave (Campbell Ave.), Toronto ON M6...  Toronto      CA
# 0  30 Eastwood Rd (Gainsborough Road), Toronto ON...  Toronto      CA
# 1    1438 Gerrard St E (Ashdale), Toronto ON M4L 1Z8  Toronto      CA
# 2                1301 Queen St E, Toronto ON M4L 1C2  Toronto      CA
# 3  1515 Gerrard St E (at Coxwell Ave), Toronto ON...  Toronto      CA
# 4          6 Coxwell Ave (Queen), Toronto ON M4L 3A7  Toronto      CA
# 5                1298 Queen St E, Toronto ON M4L 1C4  Toronto      CA
# 6  1702 Queen St E (at Kingston Rd.), Toronto ON ...  Toronto      CA
# 7  1455 Gerrard St E (Craven Rd), Toronto ON M4L 1Z9  Toronto      CA
# 8                243 Coxwell Ave, Toronto ON M4L 3B4  Toronto      CA
# 9  1338 Gerrard St E (Highfield Road), Toronto ON...  Toronto      CA
# 0  10 Dundas St E (at Yonge St.), Toronto ON M5B 2G9  Toronto      CA
# 1     1 King St W (at Yonge St.), Toronto ON M5H 1A1  Toronto      CA
# 2                1 Adelaide St E, Toronto ON M5C 2V9  Toronto      CA
# 3                 100 Front St W, Toronto ON M5J 1E3  Toronto      CA
# 4    150 King St W (at York St.), Toronto ON M5H 1J9  Toronto      CA
# 5  Sheraton Ctr (123 Queen St W), Toronto ON M5H 2M9  Toronto      CA
# 6  275 Yonge St (btwn Dundas St. E & Shuter St.),...  Toronto      CA
# 7  220 Yonge St (in Toronto Eaton Centre), Toront...  Toronto      CA
# 8  66 Wellington St W (at Bay Street), Toronto ON...  Toronto      CA
# 9                     575 Bay St, Toronto ON M5G 2C5  Toronto      CA
# 0  10 Dundas St E (at Yonge St.), Toronto ON M5B 2G9  Toronto      CA
# 1  10 Dundas St E (at Yonge St.), Toronto ON M5B 2G9  Toronto      CA
# 2    425 Church St (at Wood St.), Toronto ON M4Y 2C3  Toronto      CA
# 3  275 Yonge St (btwn Dundas St. E & Shuter St.),...  Toronto      CA
# 4        2 Bloor St E (at Yonge), Toronto ON M4W 1A8  Toronto      CA
# 5             555 University Ave, Toronto ON M5G 1X8  Toronto      CA
# 6      515 Jarvis St (Wellesley), Toronto ON M4Y 2H7  Toronto      CA
# 7     595 Bay St (Atrium on Bay), Toronto ON M5G 2C2  Toronto      CA
# 8  54 Dundas St E (at Victoria Ln.), Toronto ON M...  Toronto      CA
# 9         35 Elm St (at Bay St.), Toronto ON M5G 1H1  Toronto      CA
#
#   popularity rating
# 0   0.963599    7.4
# 1   0.962753    5.6
# 2   0.957616    6.9
# 3   0.954275    NaN
# 4   0.939122    7.4
# 5   0.935294    7.9
# 6   0.930903    5.9
# 7   0.894416    NaN
# 8   0.882665    7.1
# 9   0.864011    NaN
# 0   0.971589    NaN
# 1   0.970268    7.3
# 2   0.966415    7.8
# 3   0.946038    9.1
# 4   0.944957    NaN
# 5   0.940629    NaN
# 6   0.937177    NaN
# 7   0.934065    NaN
# 8   0.927896    NaN
# 9   0.924815    7.4
# 0   0.963599    7.4
# 1   0.957616    6.9
# 2   0.954275    NaN
# 3   0.939122    7.4
# 4   0.935294    7.9
# 5   0.894416    NaN
# 6   0.882665    7.1
# 7   0.864011    NaN
# 8   0.850605    NaN
# 9   0.849636    NaN
# 0   0.996783    7.4
# 1   0.996085    8.0
# 2   0.993146    8.4
# 3   0.991917    7.9
# 4   0.991423    7.7
# 5     0.9897    6.3
# 6   0.988138    7.5
# 7   0.987798    8.0
# 8    0.98707    9.0
# 9    0.98594    7.9
# 0   0.996783    7.4
# 1   0.996474    7.0
# 2   0.988805    8.3
# 3   0.988138    7.5
# 4   0.987984    7.1
# 5   0.984273    NaN
# 6   0.981821    8.9
# 7   0.978203    6.8
# 8    0.97727    7.0
# 9   0.976968    8.6

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
def stations_location_yelp(lat,long):
  
    url = f'https://api.yelp.com/v3/businesses/search?latitude={lat}&longitude={long}&radius=1000&categories=bars&attributes=name%2C&sort_by=rating&limit=20'
    api_key_yelp = os.environ["YELP_API_KEY"]
    headers = {
        "accept": "application/json",
        "Authorization": f'Bearer {api_key_yelp}'
               }

    response = requests.get(url, headers=headers).json()
    

    list_of_dict = []
    for poi in response['businesses']:
        loci_poi_dict = {
              'lat-long': f'{lat}, {long}'
            , 'category_name': poi['categories'][0]['alias']
            , 'categories': poi['categories']
            , 'name': poi['name']
            , 'latitude': poi['coordinates']['latitude']
            , 'longitude': poi['coordinates']['longitude']
            , 'address': poi['location']['display_address']
            , 'city': poi['location']['city']
            , 'country': poi['location']['country']
            , 'rating': poi.get('rating')
        }
        list_of_dict.append(loci_poi_dict)
    return pd.DataFrame(list_of_dict)

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
df_list_yelp = []
for i in ll_bike:
    coords=re.split('[,]',i)
    next = stations_location_yelp(coords[0],coords[1])
    #print(coords[0] + ' perica ' + coords[1])
    # print(i.get[0],i.get[1])
    df_list_yelp.append(next)

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
# Refresh df objects to avoid duplication
df_yelp = pd.DataFrame()
x = pd.DataFrame()

# Generate full df object with all locations through concatenation 
for df_i in df_list_yelp:
    x = pd.concat([df_yelp, df_i])
    df_yelp = x

# %%
df_yelp.shape
# Out:
# (10086, 10)

# %%
df_yelp.head()
# Out:
#                 lat-long category_name  \
# 0  43.665269, -79.319796      bakeries
# 1  43.665269, -79.319796          pubs
# 2  43.665269, -79.319796         cafes
# 3  43.665269, -79.319796          bars
# 4  43.665269, -79.319796  cocktailbars
#
#                                           categories                    name  \
# 0  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...         Le Conciliabule
# 1               [{'alias': 'pubs', 'title': 'Pubs'}]  Eulalie's Corner Store
# 2  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...              Black Pony
# 3  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...               Lake Inez
# 4  [{'alias': 'cocktailbars', 'title': 'Cocktail ...        Lloyd's On Queen
#
#     latitude  longitude                                            address  \
# 0  43.671365 -79.327225  [1300 Gerrard Street E, Toronto, ON M4L 1Y7, C...
# 1  43.672539 -79.321732  [1438 Gerrard Street E, Toronto, ON M4L 1Z8, C...
# 2  43.672410 -79.320400  [1481 Gerrard Street E, Toronto, ON M4L 2A3, C...
# 3  43.672340 -79.320640  [1471 Gerrard Street E, Toronto, ON M4L 2A1, C...
# 4  43.663801 -79.328356     [1298 Queen St E, Toronto, ON M4L 1C4, Canada]
#
#       city country  rating
# 0  Toronto      CA     4.5
# 1  Toronto      CA     4.5
# 2  Toronto      CA     4.5
# 3  Toronto      CA     4.5
# 4  Toronto      CA     5.0

# %%
# Save csv

filepath = Path('data/data_Yelp.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  

df_yelp.to_csv(filepath, index=False) 
df_yelp.head(50)
# Out:
#                  lat-long  category_name  \
# 0   43.665269, -79.319796       bakeries
# 1   43.665269, -79.319796           pubs
# 2   43.665269, -79.319796          cafes
# 3   43.665269, -79.319796           bars
# 4   43.665269, -79.319796   cocktailbars
# 5   43.665269, -79.319796        bowling
# 6   43.665269, -79.319796     sportsbars
# 7   43.665269, -79.319796           pubs
# 8   43.665269, -79.319796           bars
# 9   43.665269, -79.319796  mediterranean
# 10  43.665269, -79.319796           bars
# 11  43.665269, -79.319796        seafood
# 12  43.665269, -79.319796    newcanadian
# 13  43.665269, -79.319796           pubs
# 14  43.665269, -79.319796           bars
# 15  43.665269, -79.319796           bars
# 0    43.67142, -79.445947     sportsbars
# 1    43.67142, -79.445947        italian
# 2    43.67142, -79.445947           bars
# 3    43.67142, -79.445947           bars
# 4    43.67142, -79.445947           bars
# 5    43.67142, -79.445947       divebars
# 6    43.67142, -79.445947     sportsbars
# 7    43.67142, -79.445947           pubs
# 8    43.67142, -79.445947        lounges
# 9    43.67142, -79.445947       divebars
# 10   43.67142, -79.445947           bars
# 11   43.67142, -79.445947     sportsbars
# 12   43.67142, -79.445947           bars
# 13   43.67142, -79.445947           bars
# 0   43.666224, -79.317693       bakeries
# 1   43.666224, -79.317693           pubs
# 2   43.666224, -79.317693          cafes
# 3   43.666224, -79.317693           bars
# 4   43.666224, -79.317693   cocktailbars
# 5   43.666224, -79.317693        bowling
# 6   43.666224, -79.317693           pubs
# 7   43.666224, -79.317693           bars
# 8   43.666224, -79.317693  mediterranean
# 9   43.666224, -79.317693           bars
# 10  43.666224, -79.317693        seafood
# 11  43.666224, -79.317693           pubs
# 12  43.666224, -79.317693           bars
# 13  43.666224, -79.317693           bars
# 0   43.653236, -79.376716  international
# 1   43.653236, -79.376716        lounges
# 2   43.653236, -79.376716           bars
# 3   43.653236, -79.376716    newcanadian
# 4   43.653236, -79.376716   cocktailbars
# 5   43.653236, -79.376716          pizza
#
#                                            categories  \
# 0   [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 1                [{'alias': 'pubs', 'title': 'Pubs'}]
# 2   [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...
# 3   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# 4   [{'alias': 'cocktailbars', 'title': 'Cocktail ...
# 5   [{'alias': 'bowling', 'title': 'Bowling'}, {'a...
# 6   [{'alias': 'sportsbars', 'title': 'Sports Bars...
# 7   [{'alias': 'pubs', 'title': 'Pubs'}, {'alias':...
# 8   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# 9   [{'alias': 'mediterranean', 'title': 'Mediterr...
# 10               [{'alias': 'bars', 'title': 'Bars'}]
# 11  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 12  [{'alias': 'newcanadian', 'title': 'Canadian (...
# 13               [{'alias': 'pubs', 'title': 'Pubs'}]
# 14               [{'alias': 'bars', 'title': 'Bars'}]
# 15  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# 0   [{'alias': 'sportsbars', 'title': 'Sports Bars'}]
# 1   [{'alias': 'italian', 'title': 'Italian'}, {'a...
# 2                [{'alias': 'bars', 'title': 'Bars'}]
# 3   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# 4   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# 5   [{'alias': 'divebars', 'title': 'Dive Bars'}, ...
# 6   [{'alias': 'sportsbars', 'title': 'Sports Bars'}]
# 7                [{'alias': 'pubs', 'title': 'Pubs'}]
# 8   [{'alias': 'lounges', 'title': 'Lounges'}, {'a...
# 9       [{'alias': 'divebars', 'title': 'Dive Bars'}]
# 10  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# 11  [{'alias': 'sportsbars', 'title': 'Sports Bars'}]
# 12               [{'alias': 'bars', 'title': 'Bars'}]
# 13               [{'alias': 'bars', 'title': 'Bars'}]
# 0   [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 1                [{'alias': 'pubs', 'title': 'Pubs'}]
# 2   [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...
# 3   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# 4   [{'alias': 'cocktailbars', 'title': 'Cocktail ...
# 5   [{'alias': 'bowling', 'title': 'Bowling'}, {'a...
# 6   [{'alias': 'pubs', 'title': 'Pubs'}, {'alias':...
# 7   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# 8   [{'alias': 'mediterranean', 'title': 'Mediterr...
# 9                [{'alias': 'bars', 'title': 'Bars'}]
# 10  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 11               [{'alias': 'pubs', 'title': 'Pubs'}]
# 12               [{'alias': 'bars', 'title': 'Bars'}]
# 13  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# 0   [{'alias': 'international', 'title': 'Internat...
# 1          [{'alias': 'lounges', 'title': 'Lounges'}]
# 2   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# 3   [{'alias': 'newcanadian', 'title': 'Canadian (...
# 4   [{'alias': 'cocktailbars', 'title': 'Cocktail ...
# 5   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...
#
#                                     name   latitude  longitude  \
# 0                        Le Conciliabule  43.671365 -79.327225
# 1                 Eulalie's Corner Store  43.672539 -79.321732
# 2                             Black Pony  43.672410 -79.320400
# 3                              Lake Inez  43.672340 -79.320640
# 4                       Lloyd's On Queen  43.663801 -79.328356
# 5             Shamrock Bowl and Restobar  43.673290 -79.319790
# 6                          The Duke Live  43.663149 -79.330307
# 7                          JP Restaurant  43.673030 -79.319550
# 8                       The Thirsty Loon  43.672394 -79.319906
# 9                     Toronto Beach Club  43.663207 -79.310013
# 10                           Jenni Place  43.671800 -79.324810
# 11                            Beach Club  43.663207 -79.310013
# 12                          Queen's Head  43.663210 -79.330855
# 13                       Boardwalk Place  43.663010 -79.310898
# 14                        Two Headed Dog  43.672358 -79.320782
# 15          Baldev Paan Cold Drink House  43.671710 -79.323520
# 0   The Cat's Cradle  Sports and Spirits  43.677120 -79.445880
# 1                        CANO Restaurant  43.678710 -79.440580
# 2                   The Greater Good Bar  43.669269 -79.439048
# 3    Boo Radley's Junction Bar and Grill  43.666140 -79.450280
# 4                         EL TREN LATÍNO  43.677870 -79.442320
# 5                           Brothers Bar  43.679680 -79.436270
# 6                     Gaivota Sports Bar  43.665180 -79.452820
# 7                         Fox And Fiddle  43.678370 -79.439990
# 8                              Vivid Bar  43.678530 -79.439150
# 9                    This Month Only Bar  43.665670 -79.452260
# 10            La Fogata Bar & Restaurant  43.677845 -79.442411
# 11                    Castelo Sports Bar  43.675990 -79.452950
# 12                             Ti Carlos  43.676620 -79.450460
# 13                   Jhon Jhon Snack Bar  43.676102 -79.450731
# 0                        Le Conciliabule  43.671365 -79.327225
# 1                 Eulalie's Corner Store  43.672539 -79.321732
# 2                             Black Pony  43.672410 -79.320400
# 3                              Lake Inez  43.672340 -79.320640
# 4                       Lloyd's On Queen  43.663801 -79.328356
# 5             Shamrock Bowl and Restobar  43.673290 -79.319790
# 6                          JP Restaurant  43.673030 -79.319550
# 7                       The Thirsty Loon  43.672394 -79.319906
# 8                     Toronto Beach Club  43.663207 -79.310013
# 9                            Jenni Place  43.671800 -79.324810
# 10                            Beach Club  43.663207 -79.310013
# 11                       Boardwalk Place  43.663010 -79.310898
# 12                        Two Headed Dog  43.672358 -79.320782
# 13          Baldev Paan Cold Drink House  43.671710 -79.323520
# 0                Teller's Bar and Lounge  43.648820 -79.378050
# 1    TD Visa Infinite Credit Card Lounge  43.644900 -79.381573
# 2                         Ju Sushi & Bar  43.658750 -79.368220
# 3                      George Restaurant  43.653373 -79.374329
# 4        Clockwork Champagne & Cocktails  43.645950 -79.381430
# 5                 Za Cafe Pizzeria + Bar  43.651025 -79.381519
#
#                                               address     city country  rating
# 0   [1300 Gerrard Street E, Toronto, ON M4L 1Y7, C...  Toronto      CA     4.5
# 1   [1438 Gerrard Street E, Toronto, ON M4L 1Z8, C...  Toronto      CA     4.5
# 2   [1481 Gerrard Street E, Toronto, ON M4L 2A3, C...  Toronto      CA     4.5
# 3   [1471 Gerrard Street E, Toronto, ON M4L 2A1, C...  Toronto      CA     4.5
# 4      [1298 Queen St E, Toronto, ON M4L 1C4, Canada]  Toronto      CA     5.0
# 5   [280 Coxwell Avenue, Toronto, ON M4L 3B6, Canada]  Toronto      CA     4.0
# 6   [1225 Queen Street E, Toronto, ON M4M 1L6, Can...  Toronto      CA     3.5
# 7   [270 Coxwell Avenue, Toronto, ON M4L 3B6, Canada]  Toronto      CA     3.5
# 8   [1489 Gerrard Street E, Toronto, ON M4L 2A4, C...  Toronto      CA     4.0
# 9   [1681 Lake Shore Boulevard E, Toronto, ON M4L ...  Toronto      CA     3.0
# 10  [1338 Gerrard Street E, Toronto, ON M4L 1Z2, C...  Toronto      CA     3.0
# 11  [1681 Lake Shore Boulevard E, Toronto, ON M4L ...  Toronto      CA     3.0
# 12  [1214 Queen Street E, Toronto, ON M4M 1L7, Can...  Toronto      CA     2.5
# 13  [1675 Lake Shore Boulevard E, Toronto, ON M4W ...  Toronto      CA     2.5
# 14  [1469 Gerrard Street E, Toronto, ON M4L 2A1, C...  Toronto      CA     2.5
# 15  [1399 Gerrard Street E, Toronto, ON M4L 1Z5, C...  Toronto      CA     3.0
# 0   [1245 St Clair Avenue W, Toronto, ON M6E 1B8, ...  Toronto      CA     4.5
# 1   [1108 St Clair Avenue W, Toronto, ON M6E 1A7, ...  Toronto      CA     4.5
# 2     [229 Geary Avenue, Toronto, ON M6H 2C3, Canada]  Toronto      CA     4.0
# 3       [1482 Dupont Street, Toronto, ON M6P, Canada]  Toronto      CA     3.5
# 4   [1157 St. Clair Ave W, Toronto, ON M6H 2K3, Ca...  Toronto      CA     4.0
# 5   [962 St. Clair Ave W, Toronto, ON M6E 1A1, Can...  Toronto      CA     3.0
# 6   [1557 Dupont Street, Toronto, ON M6P 3S5, Canada]  Toronto      CA     3.0
# 7   [1085 Saint Clair Ave W, Toronto, ON M6E, Canada]  Toronto      CA     2.0
# 8   [1067 Staint Clair Avenue W, Toronto, ON M6E 1...  Toronto      CA     3.0
# 9   [1540 Dupont Street, Toronto, ON M6P 4G7, Canada]  Toronto      CA     1.0
# 10  [1157 St Clair Avenue W, Toronto, ON M6E 1B2, ...  Toronto      CA     1.0
# 11  [1468 Street Clair Avenue W, Toronto, ON M6E 1...  Toronto      CA     0.0
# 12  [1384 Street Clair Avenue W, Toronto, ON M6E 1...  Toronto      CA     0.0
# 13  [1351 Street Clair Avenue W, Toronto, ON M6E 1...  Toronto      CA     0.0
# 0   [1300 Gerrard Street E, Toronto, ON M4L 1Y7, C...  Toronto      CA     4.5
# 1   [1438 Gerrard Street E, Toronto, ON M4L 1Z8, C...  Toronto      CA     4.5
# 2   [1481 Gerrard Street E, Toronto, ON M4L 2A3, C...  Toronto      CA     4.5
# 3   [1471 Gerrard Street E, Toronto, ON M4L 2A1, C...  Toronto      CA     4.5
# 4      [1298 Queen St E, Toronto, ON M4L 1C4, Canada]  Toronto      CA     5.0
# 5   [280 Coxwell Avenue, Toronto, ON M4L 3B6, Canada]  Toronto      CA     4.0
# 6   [270 Coxwell Avenue, Toronto, ON M4L 3B6, Canada]  Toronto      CA     3.5
# 7   [1489 Gerrard Street E, Toronto, ON M4L 2A4, C...  Toronto      CA     4.0
# 8   [1681 Lake Shore Boulevard E, Toronto, ON M4L ...  Toronto      CA     3.0
# 9   [1338 Gerrard Street E, Toronto, ON M4L 1Z2, C...  Toronto      CA     3.0
# 10  [1681 Lake Shore Boulevard E, Toronto, ON M4L ...  Toronto      CA     3.0
# 11  [1675 Lake Shore Boulevard E, Toronto, ON M4W ...  Toronto      CA     2.5
# 12  [1469 Gerrard Street E, Toronto, ON M4L 2A1, C...  Toronto      CA     2.5
# 13  [1399 Gerrard Street E, Toronto, ON M4L 1Z5, C...  Toronto      CA     3.0
# 0   [One King West Hotel & Residence, 1 King Stree...  Toronto      CA     4.5
# 1   [65 Front Street West, Toronto, ON M5J 1E6, Ca...  Toronto      CA     4.5
# 2   [383 Dundas Street E, Toronto, ON M5A 2A6, Can...  Toronto      CA     4.5
# 3   [111 Queen Street E, Toronto, ON M5C 1S2, Canada]  Toronto      CA     4.5
# 4   [100 Front Street W, Toronto, ON M5J 1E3, Canada]  Toronto      CA     4.0
# 5       [372 Bay Street, Toronto, ON M5H 2W9, Canada]  Toronto      CA     4.0

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %%
per_station_poi_fsq=df_fsq.groupby('lat-long').fsq_id.count()
per_station_poi_fsq.describe()
# Out:
# count    638.000000
# mean       9.086207
# std        2.242818
# min        1.000000
# 25%       10.000000
# 50%       10.000000
# 75%       10.000000
# max       10.000000
# Name: fsq_id, dtype: float64

# %%
per_station_poi_yelp=df_yelp.groupby('lat-long').category_name.count()
per_station_poi_yelp.describe()
# Out:
# count    638.000000
# mean      15.808777
# std        6.472581
# min        1.000000
# 25%       11.250000
# 50%       20.000000
# 75%       20.000000
# max       20.000000
# Name: category_name, dtype: float64

# %% [markdown]
# When I compare FSQ and Yelp, I find FSQ much more intuitive to use.
# There is a much larger selection of components that I can include in FSQ. The only advantage I've seen of Yelp is that within its GET method, you can set a limit on how many POIs you want to display per location. I limited Yeal to 20 (max 20), which is certainly more than FSQ (max 10).

# %% [markdown]
# Get the top 10 restaurants according to their rating

# %%
#df_fsq.head()
df_fsq.sort_values(by=['rating'], ascending=False).head(10)
# Out:
#                         lat-long                    fsq_id  cat_id  \
# 3           43.681944,-79.390556  52ced2c9498e67e1059cf3b2   13059
# 3  43.6846177,-79.39245919999999  52ced2c9498e67e1059cf3b2   13059
# 7           43.669903,-79.387802  5bd2379cbcbf7a0039a2d7b9   13003
# 3            43.671526,-79.44874  5753753b498eeb535c53aed5   13003
# 5           43.671944,-79.387778  5bd2379cbcbf7a0039a2d7b9   13003
# 9           43.663102,-79.373181  5bd2379cbcbf7a0039a2d7b9   13003
# 0           43.672453,-79.338259  52ec057a11d23d4bcd3e74e7   13029
# 9             43.66663,-79.38148  5bd2379cbcbf7a0039a2d7b9   13003
# 3         43.6741219,-79.4352208  5753753b498eeb535c53aed5   13003
# 4            43.665327,-79.43235  5753753b498eeb535c53aed5   13003
#
#   category_name                                         categories  \
# 3     Juice Bar  [{'id': 13059, 'name': 'Juice Bar', 'icon': {'...
# 3     Juice Bar  [{'id': 13059, 'name': 'Juice Bar', 'icon': {'...
# 7           Bar  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...
# 3           Bar  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...
# 5           Bar  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...
# 9           Bar  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...
# 0       Brewery  [{'id': 13029, 'name': 'Brewery', 'icon': {'pr...
# 9           Bar  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...
# 3           Bar  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...
# 4           Bar  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...
#
#                    name                                            address  \
# 3   Greenhouse Juice Co   5 MacPherson Ave (Yonge St.), Toronto ON M5R 1W7
# 3   Greenhouse Juice Co   5 MacPherson Ave (Yonge St.), Toronto ON M5R 1W7
# 7      Storm Crow Manor                  580 Church St, Toronto ON M4Y 2E5
# 3  The Greater Good Bar  229 Geary Ave (at Dufferin St), Toronto ON M6H...
# 5      Storm Crow Manor                  580 Church St, Toronto ON M4Y 2E5
# 9      Storm Crow Manor                  580 Church St, Toronto ON M4Y 2E5
# 0    Left Field Brewery  36 Wagstaff Dr (Greenwood Ave. and Gerrard Str...
# 9      Storm Crow Manor                  580 Church St, Toronto ON M4Y 2E5
# 3  The Greater Good Bar  229 Geary Ave (at Dufferin St), Toronto ON M6H...
# 4  The Greater Good Bar  229 Geary Ave (at Dufferin St), Toronto ON M6H...
#
#       city country popularity rating
# 3  Toronto      CA    0.92944    9.2
# 3  Toronto      CA    0.92944    9.2
# 7  Toronto      CA   0.968008    9.1
# 3  Toronto      CA   0.946038    9.1
# 5  Toronto      CA   0.968008    9.1
# 9  Toronto      CA   0.968008    9.1
# 0  Toronto      CA   0.975393    9.1
# 9  Toronto      CA   0.968008    9.1
# 3  Toronto      CA   0.946038    9.1
# 4  Toronto      CA   0.946038    9.1

# %%
#df_yelp.head()
df_yelp.sort_values(by=['rating'], ascending=False).head(10)
# Out:
#                    lat-long    category_name  \
# 18    43.636804, -79.408832             bars
# 11      43.66587, -79.33443            cuban
# 5   43.6702236, -79.4360232     cocktailbars
# 9     43.649722, -79.416944      musicvenues
# 1       43.66587, -79.33443  tapasmallplates
# 8      43.651238, -79.43868             bars
# 6      43.651238, -79.43868             bars
# 6       43.66587, -79.33443     cocktailbars
# 1     43.649722, -79.416944     cocktailbars
# 10      43.66587, -79.33443     cocktailbars
#
#                                            categories  \
# 18               [{'alias': 'bars', 'title': 'Bars'}]
# 11  [{'alias': 'cuban', 'title': 'Cuban'}, {'alias...
# 5   [{'alias': 'cocktailbars', 'title': 'Cocktail ...
# 9   [{'alias': 'musicvenues', 'title': 'Music Venu...
# 1   [{'alias': 'tapasmallplates', 'title': 'Tapas/...
# 8   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# 6                [{'alias': 'bars', 'title': 'Bars'}]
# 6   [{'alias': 'cocktailbars', 'title': 'Cocktail ...
# 1   [{'alias': 'cocktailbars', 'title': 'Cocktail ...
# 10  [{'alias': 'cocktailbars', 'title': 'Cocktail ...
#
#                         name   latitude  longitude  \
# 18                 Sensorium  43.644686 -79.398242
# 11                Bar Habana  43.668997 -79.337163
# 5                 915 Dupont  43.670099 -79.429762
# 9           Poetry Jazz Café  43.643768 -79.421750
# 1              East End Vine  43.666996 -79.344665
# 8                    BSMT254  43.651203 -79.440232
# 6              Blue Bird Bar  43.652270 -79.447950
# 6                    Wei Bar  43.661560 -79.339050
# 1   Prequel & Co. Apothecary  43.644141 -79.420339
# 10          Lloyd's On Queen  43.663801 -79.328356
#
#                                               address     city country  rating
# 18       [525 King Street W, Toronto, ON M5V, Canada]  Toronto      CA     5.0
# 11  [1030 Gerrard Street E, Toronto, ON M4M 1Z5, C...  Toronto      CA     5.0
# 5    [915 Dupont Street, Toronto, ON M6H 1Z1, Canada]  Toronto      CA     5.0
# 9   [1078 Queen Street W, Toronto, ON M6J 1H8, Can...  Toronto      CA     5.0
# 1   [817 Gerrard Street E, Toronto, ON M4M 1Y8, Ca...  Toronto      CA     5.0
# 8   [254 Lansdowne Avenue, Toronto, ON M6H 3X9, Ca...  Toronto      CA     5.0
# 6   [2072 Dundas Street W, Toronto, ON M6R 1W9, Ca...  Toronto      CA     5.0
# 6      [1014 Queen St E, Toronto, ON M4M 1K1, Canada]  Toronto      CA     5.0
# 1   [1036 Queen Street W, Toronto, ON M6J 1H7, Can...  Toronto      CA     5.0
# 10     [1298 Queen St E, Toronto, ON M4L 1C4, Canada]  Toronto      CA     5.0
